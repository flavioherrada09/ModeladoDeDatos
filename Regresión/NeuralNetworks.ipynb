# %% [markdown]
# ___
# <img style="float: right; margin: 0px 0px 15px 15px;" src="https://bernardmarr.com/img/What%20is%20an%20Artificial%20Neural%20Networks.jpg" width="350px" height="180px" />
#
#
# # <font color= #8A0829> Laboratorio de Modelado de Datos </font>
# - <Strong> Flavio Maximiliano Herrada Avalos</Strong>
# - <Strong> Año </Strong>: 2021
# - <Strong> Email: </Strong>  <font color="blue"> `flavio.herrada@iteso.mx` </font>
# ___
#
# <p style="text-align:right;"> Imagen recuperada de: https://bernardmarr.com/img/What%20is%20an%20Artificial%20Neural%20Networks.jpg</p>
#
# ### <font color= #2E9AFE> Tema: Redes Neuronales</font>

# %% [markdown]
# **Aplicaciones de la vida real**
#
# - Control del vuelo de aviones
# - Control automotriz
# - Área médica
# - Optimizar el rendimiento del Wi-fi

# %%
from IPython.display import Image
Image(filename='compare_NN.JPG', width=600, height=400)

# %% [markdown]
# Dentro de la caja negra...
#
# **¿Qué es una neurona?**
#
# Es un nombre elegante que le pusieron para referirse a una función en los años de 1940-1950. Se creeía que los nodos eran como neuronas del cerebro.
#
# **¿Qué es una función?**
#
# Es un nombre elegante que pusieron para referirse a algo que toma cosas de entrada, aplica alguna lógica y saca un resultado.
#
# **¿Qué es una red neuronal?**
#
# Es la interconexión de múltiples neuronas (funciones) para resolver un problema complejo que una sola neurona no podría. Dentro de los componentes existen *nodos* y *conexiones*
#
# **Pasos que hace la red neuronal:**
#
# 1. Combinación de las variables de entrada (X). Cada señal recibida tiene una constante w (peso/weight) que permite manipular la importancia de cada variable de entrada.
# 2. Neurona de respuesta. Considerando todas las variables de entrada, la neurona genera una señal de respuesta a través de una función.
#
# **Tipos de capas en la red neuronal**
#
# - Capa de entrada: capa que toma los datos de entrada
# - Capas ocultas: toman las entradas de otra capa y pasan a salida hacia otra capa (son intermediarias entre la entrada y la salida)
# - Capas de salida: capa que hace la predicción
#
# <img style="float: center; margin: 0px 0px 0px 0px;" src="https://www.smartsheet.com/sites/default/files/IC-simplified-artificial-neural-networks-corrected.svg" width="350px" height="180px" />

# %%
from IPython.display import Image
Image(filename='neuron_weights.JPG', width=300, height=200)

# %% [markdown]
# **Modelo matemático de la neurona**
#
# $$\nu = w_{0}+w_{1}x_{1}+w_{2}x_{2}+w_{3}x_{3}+w_{4}x_{4}+w_{5}x_{5}$$
# $$y = \varphi(\nu)$$

# %%
from IPython.display import Image
Image(filename='capa_oculta.JPG', width=300, height=200)

# %% [markdown]
# **Modelo matemático red neuronal**
#
# $$\nu^{1} = w_{0}^{1}+w^{1}$$
# $$y^{1} = \varphi(\nu^{1})$$
# $$\nu^{2} = w_{0}^{2}+w^{2}y_{1}$$
# $$y^{2} = \varphi(\nu^{2})$$

# %%
from IPython.display import Image
Image(filename='capa_oculta2.JPG', width=300, height=200)

# %% [markdown]
# **Modelo matemático usando dos capas oculta**
#
# <font color= #66CC00>$$\nu^{1} = w_{0}^{1}+w^{1}$$</font>
# <font color= #66CC00>$$y^{1} = \varphi(\nu^{1})$$</font>
# <font color= #009900>$$\nu^{2} = w_{0}^{2}+w^{2}y_{1}$$</font>
# <font color= #009900>$$y^{2} = \varphi(\nu^{2})$$</font>
# <font color= #3399FF>$$\nu^{3} = w_{0}^{3}+w^{3}y_{2}$$</font>
# <font color= #3399FF>$$y^{3} = \varphi(\nu^{3})$$</font>
#
#
# **Funciones de activación**
#
# El comportamiento de las neuronas de las redes neuronales es basado en la función en la que la neurona se especializó. Una neurona puede cambiar su respuesta dependiendo de la función de activación $\varphi(*)$ que sea seleccionada
#
# Funciones comunes:
# 1. Lineal: $\varphi(\nu)=\nu$
# 2. Sigmoidal: $\varphi(\nu)=\frac{e^{\nu}}{1+e^{\nu}}$
# 3. Tanh: $\varphi(\nu)=\frac{e^{\nu}-e^{-\nu}}{e^{\nu}+e^{-\nu}}=tanh(\nu)$
# 4. Softplus: $\varphi(\nu)=log(1+e^{\nu})$
# 5. RELU: $\varphi(\nu)=max(0,\nu)$
#
# Las funciones de activación suelen ser diferenciables, lo que significa que la derivada de primer orden se puede calcular para un valor de entrada dado. Esto es necesario dado que las redes neuronales generalmente se entrenan utilizando el algoritmo de backpropagation que requiere la derivada del error de predicción para actualizar los pesos del modelo.
#
# **¿Cómo elegir la función de activación para las capas ocultas?**
#
# - Lineal: se recomienda para cuando el problema es sencillo
# - Sigmoidal: típicamente para problemas de clasificación. Sufre del problema de "Gradiente que se desvanece", los gradientes de la salida de la red con respecto a los parámetros se vuelven tan pequeños que la red neuronal da pasos más pequeños hacia los mínimos de la función de costo y finalmente deja de aprender.
# - Tanh: muy similar a la sigmoidal
# - RELU: es la más utilizada para capas ocultas. Es simple de implementar y no es tan susceptible a gradientes que se desvanecen
# - Softmax: no se recomienda mucho usarla ya que el cálculo de gradientes no es tan eficiente
#
# **¿Cómo son las redes neuronales para regresión?**
#
# $$\nu^{1} = w_{0}^{1}+w^{1}$$
# $$y^{1} = \varphi(\nu^{1})$$
# $$\nu^{2} = w_{0}^{2}+w^{2}y_{1}$$
# <font color= #2E9AFE>$$y^{2} = \varphi(\nu^{2})$$</font>
#
# La única diferencia es la última salida. La función de la salida tiene que ser **lineal**
#
# **Backpropagation**
#
# Es el método que usa para ajustar el modelo. Minimiza el error medio cuadrático (MSE), utilizando el gradiente descendente para calcular los parámetros con el orden del último hacia el primero.
#
# **¿Cómo elegir cuántas capas ocultas?**
#
# Se recomienda usar la regla de:
# (# capas ocultas = #entradas + # salidas)
#
# **¿Cómo elegir cuántas neuronas en las capas ocultas?**
#
# Depende....
#
# De forma ideal, el número de neuronas ocultas debe ser mayor al número de entradas (#Neuronas ocultas > # variables de entrada).
#
# Peroooo esta regla tiene varias formas de verse afectada:
#
# 1. Número de datos
# 2. Poder computacional
#
# Si se tienen pocos datos, al aumentar el número de neuronas ocultas, la cantidad de pesos se empieza a ser comparable con las muestras que se tienen, entonces conviene aumentar la cantidad de neuronas ocultas.
#
# Si se tienen muchos datos, esta regla de (#Neuronas ocultas > # variables de entrada) no es fácil por cuestiones computacionales, por lo tanto usamos las siguientes reglas:
#
# - El número de neuronas ocultas debe estar entre el tamaño de la capa de entrada y el tamaño de la capa de salida.
# - El número de neuronas ocultas debe ser 2/3 del tamaño de la capa de entrada, más el tamaño de la capa de salida.
# - El número de neuronas ocultas es la media de las neuronas en las capas de entrada y salida.
#
# **Recomendaciones**
#
# - Se recomienda hacer un pre-procesamiento de los datos - Escalamiento
# - Comúnmente todas las capas ocultas usan la misma función de activación
# - La función de salida generalmente usa diferente función de activación que el de las capas ocultas.
# - En la experiencia, conviene más aumentar el número de neuronas ocultas en lugar de aumentar el número de capas ocultas.
# - Se recomienda no usar muchas capas ocultas

# %%
#conda install -c conda-forge keras
#conda install -c conda-forge/label/broken keras
#conda install -c conda-forge/label/cf201901 keras
#conda install -c conda-forge tensorflow=1.14
#pip install keras
#pip install tensorflow
import tensorflow as tf
import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation
from keras.optimizers import SGD, Adam
from tensorflow.keras.optimizers import SGD
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import r2_score

# %%
import keras

# %% [markdown]
# #### Ejemplo de una sola variable (X)

# %%
import tensorflow as tf

# %%
#Generamos datos
#Generar la X
m = 1000;
X = np.linspace(-1,1,num=m)
X = np.reshape(X,(m,1))

#Generar la Y

#Y = X**2 #Función cuadrática
Y = 2*X**3+2*X**2 
#Y = 4*X*np.sin(10*X)+X*np.exp(X)*np.cos(20*X) 

[m,ne] = np.shape(X)

from sklearn import preprocessing
X = preprocessing.scale(X)
Y = preprocessing.scale(Y)

#graficando los datos
fig = plt.figure()
plt.plot(X,Y, linewidth=3)
plt.grid()

# %%
#Dividimos los datos en test y train
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, Y,
                                                    test_size=0.2, random_state=42)

# %%
# Diseño del modelo

#Inicializo objeto
model = Sequential()

#Agregar capas

#Agregamos la primera capa de entrada
#capa densa significa que todas las neuronas anteriores van con todas las que siguen
#Elegimos 5 neuronas en esa capa
#input_dim = 1 porque tenemos solo una X. Aquí nos preguntamos: ¿cuántas entradas voy a tener?
model.add(Dense(5, activation='relu', input_dim=1,name='input_layer'))


#si quisiéramos añadir capas ocultas
#model.add(Dense(10, activation='tanh', name='hidden_layer'))

#Agregamos la capa de salida
#la capa de salida tiene que ser lineal
model.add(Dense(1, activation='linear',name='output_layer'))




#gradiente descendente
#épocas = cuántas veces se repite el gradiente descendente para encontrar el mínimo del MSE
#si la funcion de costo J tiene muchos picos, se recomienda disminuir el decaimineto o aumentar la tasa de aprendizaje
#Momentum: Utiliza la ley física del movimiento para atravesar óptimos locales (pequeñas colinas). 
#agrega un impulso que hará que la convergencia sea más rápida

#Hiperparámetros
learning_rate=0.1
epochs = 200
momentum = 0.8
decay_rate = learning_rate/epochs
sgd = SGD(lr=learning_rate, decay=decay_rate, momentum=momentum)


model.compile(loss='mean_squared_error',
              optimizer=sgd, 
             metrics = ['mse'])
# Out:
# /Users/kalebavila/miniforge3/envs/keras/lib/python3.8/site-packages/keras/optimizers/optimizer_v2/gradient_descent.py:111: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)

# %%
#Ajustamos el modelo
history = model.fit(X_train, y_train, 
                   epochs=epochs, 
                   batch_size=100, 
                   validation_data=(X_test,y_test))
# Out:
# Epoch 1/200
# 8/8 [==============================] - 1s 16ms/step - loss: 0.8262 - mse: 0.8262 - val_loss: 0.6655 - val_mse: 0.6655
# Epoch 2/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.4309 - mse: 0.4309 - val_loss: 0.3238 - val_mse: 0.3238
# Epoch 3/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2061 - mse: 0.2061 - val_loss: 0.1180 - val_mse: 0.1180
# Epoch 4/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0752 - mse: 0.0752 - val_loss: 0.0517 - val_mse: 0.0517
# Epoch 5/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0368 - mse: 0.0368 - val_loss: 0.0299 - val_mse: 0.0299
# Epoch 6/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0254 - mse: 0.0254 - val_loss: 0.0276 - val_mse: 0.0276
# Epoch 7/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0214 - mse: 0.0214 - val_loss: 0.0196 - val_mse: 0.0196
# Epoch 8/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0194 - mse: 0.0194 - val_loss: 0.0190 - val_mse: 0.0190
# Epoch 9/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0217 - mse: 0.0217 - val_loss: 0.0242 - val_mse: 0.0242
# Epoch 10/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0203 - mse: 0.0203 - val_loss: 0.0187 - val_mse: 0.0187
# Epoch 11/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0190 - mse: 0.0190 - val_loss: 0.0207 - val_mse: 0.0207
# Epoch 12/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0193 - mse: 0.0193 - val_loss: 0.0196 - val_mse: 0.0196
# Epoch 13/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0204 - mse: 0.0204 - val_loss: 0.0197 - val_mse: 0.0197
# Epoch 14/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0186 - mse: 0.0186 - val_loss: 0.0200 - val_mse: 0.0200
# Epoch 15/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0196 - mse: 0.0196 - val_loss: 0.0231 - val_mse: 0.0231
# Epoch 16/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0202 - mse: 0.0202 - val_loss: 0.0184 - val_mse: 0.0184
# Epoch 17/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0197 - mse: 0.0197 - val_loss: 0.0194 - val_mse: 0.0194
# Epoch 18/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0203 - mse: 0.0203 - val_loss: 0.0212 - val_mse: 0.0212
# Epoch 19/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0202 - mse: 0.0202 - val_loss: 0.0216 - val_mse: 0.0216
# Epoch 20/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0193 - mse: 0.0193 - val_loss: 0.0187 - val_mse: 0.0187
# Epoch 21/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0187 - mse: 0.0187 - val_loss: 0.0204 - val_mse: 0.0204
# Epoch 22/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0187 - mse: 0.0187 - val_loss: 0.0186 - val_mse: 0.0186
# Epoch 23/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0185 - mse: 0.0185 - val_loss: 0.0192 - val_mse: 0.0192
# Epoch 24/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0187 - mse: 0.0187 - val_loss: 0.0190 - val_mse: 0.0190
# Epoch 25/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0185 - mse: 0.0185 - val_loss: 0.0187 - val_mse: 0.0187
# Epoch 26/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0183 - mse: 0.0183 - val_loss: 0.0188 - val_mse: 0.0188
# Epoch 27/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0188 - mse: 0.0188 - val_loss: 0.0191 - val_mse: 0.0191
# Epoch 28/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0189 - mse: 0.0189 - val_loss: 0.0182 - val_mse: 0.0182
# Epoch 29/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0183 - mse: 0.0183 - val_loss: 0.0179 - val_mse: 0.0179
# Epoch 30/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0191 - mse: 0.0191 - val_loss: 0.0187 - val_mse: 0.0187
# Epoch 31/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0188 - mse: 0.0188 - val_loss: 0.0192 - val_mse: 0.0192
# Epoch 32/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0183 - mse: 0.0183 - val_loss: 0.0182 - val_mse: 0.0182
# Epoch 33/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0193 - mse: 0.0193 - val_loss: 0.0185 - val_mse: 0.0185
# Epoch 34/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0182 - mse: 0.0182 - val_loss: 0.0200 - val_mse: 0.0200
# Epoch 35/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0190 - mse: 0.0190 - val_loss: 0.0196 - val_mse: 0.0196
# Epoch 36/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0203 - mse: 0.0203 - val_loss: 0.0181 - val_mse: 0.0181
# Epoch 37/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0189 - mse: 0.0189 - val_loss: 0.0181 - val_mse: 0.0181
# Epoch 38/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0190 - mse: 0.0190 - val_loss: 0.0189 - val_mse: 0.0189
# Epoch 39/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0190 - mse: 0.0190 - val_loss: 0.0191 - val_mse: 0.0191
# Epoch 40/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0188 - mse: 0.0188 - val_loss: 0.0214 - val_mse: 0.0214
# Epoch 41/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0186 - mse: 0.0186 - val_loss: 0.0196 - val_mse: 0.0196
# Epoch 42/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0197 - mse: 0.0197 - val_loss: 0.0196 - val_mse: 0.0196
# Epoch 43/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0185 - mse: 0.0185 - val_loss: 0.0190 - val_mse: 0.0190
# Epoch 44/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0180 - mse: 0.0180 - val_loss: 0.0181 - val_mse: 0.0181
# Epoch 45/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0185 - mse: 0.0185 - val_loss: 0.0198 - val_mse: 0.0198
# Epoch 46/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0193 - mse: 0.0193 - val_loss: 0.0194 - val_mse: 0.0194
# Epoch 47/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0189 - mse: 0.0189 - val_loss: 0.0195 - val_mse: 0.0195
# Epoch 48/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0190 - mse: 0.0190 - val_loss: 0.0204 - val_mse: 0.0204
# Epoch 49/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0191 - mse: 0.0191 - val_loss: 0.0185 - val_mse: 0.0185
# Epoch 50/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0186 - mse: 0.0186 - val_loss: 0.0179 - val_mse: 0.0179
# Epoch 51/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0190 - mse: 0.0190 - val_loss: 0.0238 - val_mse: 0.0238
# Epoch 52/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0198 - mse: 0.0198 - val_loss: 0.0182 - val_mse: 0.0182
# Epoch 53/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0192 - mse: 0.0192 - val_loss: 0.0184 - val_mse: 0.0184
# Epoch 54/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0185 - mse: 0.0185 - val_loss: 0.0194 - val_mse: 0.0194
# Epoch 55/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0189 - mse: 0.0189 - val_loss: 0.0181 - val_mse: 0.0181
# Epoch 56/200
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0190 - mse: 0.0190 - val_loss: 0.0221 - val_mse: 0.0221
# Epoch 57/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0197 - mse: 0.0197 - val_loss: 0.0181 - val_mse: 0.0181
# Epoch 58/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0182 - mse: 0.0182 - val_loss: 0.0192 - val_mse: 0.0192
# Epoch 59/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0184 - mse: 0.0184 - val_loss: 0.0195 - val_mse: 0.0195
# Epoch 60/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0183 - mse: 0.0183 - val_loss: 0.0184 - val_mse: 0.0184
# Epoch 61/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0194 - mse: 0.0194 - val_loss: 0.0178 - val_mse: 0.0178
# Epoch 62/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0188 - mse: 0.0188 - val_loss: 0.0185 - val_mse: 0.0185
# Epoch 63/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0181 - mse: 0.0181 - val_loss: 0.0189 - val_mse: 0.0189
# Epoch 64/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0181 - mse: 0.0181 - val_loss: 0.0180 - val_mse: 0.0180
# Epoch 65/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0190 - mse: 0.0190 - val_loss: 0.0210 - val_mse: 0.0210
# Epoch 66/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0203 - mse: 0.0203 - val_loss: 0.0179 - val_mse: 0.0179
# Epoch 67/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0207 - mse: 0.0207 - val_loss: 0.0186 - val_mse: 0.0186
# Epoch 68/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0182 - mse: 0.0182 - val_loss: 0.0183 - val_mse: 0.0183
# Epoch 69/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0200 - mse: 0.0200 - val_loss: 0.0202 - val_mse: 0.0202
# Epoch 70/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0188 - mse: 0.0188 - val_loss: 0.0183 - val_mse: 0.0183
# Epoch 71/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0185 - mse: 0.0185 - val_loss: 0.0182 - val_mse: 0.0182
# Epoch 72/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0186 - mse: 0.0186 - val_loss: 0.0186 - val_mse: 0.0186
# Epoch 73/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0187 - mse: 0.0187 - val_loss: 0.0178 - val_mse: 0.0178
# Epoch 74/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0179 - mse: 0.0179 - val_loss: 0.0182 - val_mse: 0.0182
# Epoch 75/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0186 - mse: 0.0186 - val_loss: 0.0180 - val_mse: 0.0180
# Epoch 76/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0182 - mse: 0.0182 - val_loss: 0.0180 - val_mse: 0.0180
# Epoch 77/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0188 - mse: 0.0188 - val_loss: 0.0187 - val_mse: 0.0187
# Epoch 78/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0192 - mse: 0.0192 - val_loss: 0.0185 - val_mse: 0.0185
# Epoch 79/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0181 - mse: 0.0181 - val_loss: 0.0186 - val_mse: 0.0186
# Epoch 80/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0186 - mse: 0.0186 - val_loss: 0.0183 - val_mse: 0.0183
# Epoch 81/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0179 - mse: 0.0179 - val_loss: 0.0183 - val_mse: 0.0183
# Epoch 82/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0183 - mse: 0.0183 - val_loss: 0.0189 - val_mse: 0.0189
# Epoch 83/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0200 - mse: 0.0200 - val_loss: 0.0181 - val_mse: 0.0181
# Epoch 84/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0192 - mse: 0.0192 - val_loss: 0.0180 - val_mse: 0.0180
# Epoch 85/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0186 - mse: 0.0186 - val_loss: 0.0199 - val_mse: 0.0199
# Epoch 86/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0180 - mse: 0.0180 - val_loss: 0.0209 - val_mse: 0.0209
# Epoch 87/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0200 - mse: 0.0200 - val_loss: 0.0203 - val_mse: 0.0203
# Epoch 88/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0188 - mse: 0.0188 - val_loss: 0.0183 - val_mse: 0.0183
# Epoch 89/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0184 - mse: 0.0184 - val_loss: 0.0183 - val_mse: 0.0183
# Epoch 90/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0184 - mse: 0.0184 - val_loss: 0.0180 - val_mse: 0.0180
# Epoch 91/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0180 - mse: 0.0180 - val_loss: 0.0181 - val_mse: 0.0181
# Epoch 92/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0190 - mse: 0.0190 - val_loss: 0.0199 - val_mse: 0.0199
# Epoch 93/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0200 - mse: 0.0200 - val_loss: 0.0182 - val_mse: 0.0182
# Epoch 94/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0185 - mse: 0.0185 - val_loss: 0.0182 - val_mse: 0.0182
# Epoch 95/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0182 - mse: 0.0182 - val_loss: 0.0183 - val_mse: 0.0183
# Epoch 96/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0186 - mse: 0.0186 - val_loss: 0.0189 - val_mse: 0.0189
# Epoch 97/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0186 - mse: 0.0186 - val_loss: 0.0182 - val_mse: 0.0182
# Epoch 98/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0190 - mse: 0.0190 - val_loss: 0.0180 - val_mse: 0.0180
# Epoch 99/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0186 - mse: 0.0186 - val_loss: 0.0186 - val_mse: 0.0186
# Epoch 100/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0184 - mse: 0.0184 - val_loss: 0.0181 - val_mse: 0.0181
# Epoch 101/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0186 - mse: 0.0186 - val_loss: 0.0217 - val_mse: 0.0217
# Epoch 102/200
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0199 - mse: 0.0199 - val_loss: 0.0188 - val_mse: 0.0188
# Epoch 103/200
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0189 - mse: 0.0189 - val_loss: 0.0187 - val_mse: 0.0187
# Epoch 104/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0184 - mse: 0.0184 - val_loss: 0.0191 - val_mse: 0.0191
# Epoch 105/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0182 - mse: 0.0182 - val_loss: 0.0180 - val_mse: 0.0180
# Epoch 106/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0184 - mse: 0.0184 - val_loss: 0.0200 - val_mse: 0.0200
# Epoch 107/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0186 - mse: 0.0186 - val_loss: 0.0183 - val_mse: 0.0183
# Epoch 108/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0197 - mse: 0.0197 - val_loss: 0.0191 - val_mse: 0.0191
# Epoch 109/200
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0205 - mse: 0.0205 - val_loss: 0.0183 - val_mse: 0.0183
# Epoch 110/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0184 - mse: 0.0184 - val_loss: 0.0181 - val_mse: 0.0181
# Epoch 111/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0188 - mse: 0.0188 - val_loss: 0.0205 - val_mse: 0.0205
# Epoch 112/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0191 - mse: 0.0191 - val_loss: 0.0181 - val_mse: 0.0181
# Epoch 113/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0186 - mse: 0.0186 - val_loss: 0.0186 - val_mse: 0.0186
# Epoch 114/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0182 - mse: 0.0182 - val_loss: 0.0179 - val_mse: 0.0179
# Epoch 115/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0182 - mse: 0.0182 - val_loss: 0.0183 - val_mse: 0.0183
# Epoch 116/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0180 - mse: 0.0180 - val_loss: 0.0183 - val_mse: 0.0183
# Epoch 117/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0183 - mse: 0.0183 - val_loss: 0.0189 - val_mse: 0.0189
# Epoch 118/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0185 - mse: 0.0185 - val_loss: 0.0182 - val_mse: 0.0182
# Epoch 119/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0185 - mse: 0.0185 - val_loss: 0.0185 - val_mse: 0.0185
# Epoch 120/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0188 - mse: 0.0188 - val_loss: 0.0178 - val_mse: 0.0178
# Epoch 121/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0190 - mse: 0.0190 - val_loss: 0.0194 - val_mse: 0.0194
# Epoch 122/200
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0181 - mse: 0.0181 - val_loss: 0.0181 - val_mse: 0.0181
# Epoch 123/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0182 - mse: 0.0182 - val_loss: 0.0186 - val_mse: 0.0186
# Epoch 124/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0187 - mse: 0.0187 - val_loss: 0.0189 - val_mse: 0.0189
# Epoch 125/200
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0181 - mse: 0.0181 - val_loss: 0.0179 - val_mse: 0.0179
# Epoch 126/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0187 - mse: 0.0187 - val_loss: 0.0180 - val_mse: 0.0180
# Epoch 127/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0181 - mse: 0.0181 - val_loss: 0.0189 - val_mse: 0.0189
# Epoch 128/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0187 - mse: 0.0187 - val_loss: 0.0186 - val_mse: 0.0186
# Epoch 129/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0183 - mse: 0.0183 - val_loss: 0.0194 - val_mse: 0.0194
# Epoch 130/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0189 - mse: 0.0189 - val_loss: 0.0179 - val_mse: 0.0179
# Epoch 131/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0186 - mse: 0.0186 - val_loss: 0.0185 - val_mse: 0.0185
# Epoch 132/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0182 - mse: 0.0182 - val_loss: 0.0179 - val_mse: 0.0179
# Epoch 133/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0183 - mse: 0.0183 - val_loss: 0.0179 - val_mse: 0.0179
# Epoch 134/200
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0183 - mse: 0.0183 - val_loss: 0.0183 - val_mse: 0.0183
# Epoch 135/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0188 - mse: 0.0188 - val_loss: 0.0190 - val_mse: 0.0190
# Epoch 136/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0184 - mse: 0.0184 - val_loss: 0.0184 - val_mse: 0.0184
# Epoch 137/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0185 - mse: 0.0185 - val_loss: 0.0180 - val_mse: 0.0180
# Epoch 138/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0179 - mse: 0.0179 - val_loss: 0.0188 - val_mse: 0.0188
# Epoch 139/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0180 - mse: 0.0180 - val_loss: 0.0198 - val_mse: 0.0198
# Epoch 140/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0182 - mse: 0.0182 - val_loss: 0.0183 - val_mse: 0.0183
# Epoch 141/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0192 - mse: 0.0192 - val_loss: 0.0189 - val_mse: 0.0189
# Epoch 142/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0182 - mse: 0.0182 - val_loss: 0.0180 - val_mse: 0.0180
# Epoch 143/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0183 - mse: 0.0183 - val_loss: 0.0183 - val_mse: 0.0183
# Epoch 144/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0181 - mse: 0.0181 - val_loss: 0.0193 - val_mse: 0.0193
# Epoch 145/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0196 - mse: 0.0196 - val_loss: 0.0185 - val_mse: 0.0185
# Epoch 146/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0192 - mse: 0.0192 - val_loss: 0.0179 - val_mse: 0.0179
# Epoch 147/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0185 - mse: 0.0185 - val_loss: 0.0201 - val_mse: 0.0201
# Epoch 148/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0188 - mse: 0.0188 - val_loss: 0.0181 - val_mse: 0.0181
# Epoch 149/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0183 - mse: 0.0183 - val_loss: 0.0181 - val_mse: 0.0181
# Epoch 150/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0183 - mse: 0.0183 - val_loss: 0.0183 - val_mse: 0.0183
# Epoch 151/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0181 - mse: 0.0181 - val_loss: 0.0179 - val_mse: 0.0179
# Epoch 152/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0180 - mse: 0.0180 - val_loss: 0.0184 - val_mse: 0.0184
# Epoch 153/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0184 - mse: 0.0184 - val_loss: 0.0196 - val_mse: 0.0196
# Epoch 154/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0198 - mse: 0.0198 - val_loss: 0.0179 - val_mse: 0.0179
# Epoch 155/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0179 - mse: 0.0179 - val_loss: 0.0185 - val_mse: 0.0185
# Epoch 156/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0182 - mse: 0.0182 - val_loss: 0.0193 - val_mse: 0.0193
# Epoch 157/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0183 - mse: 0.0183 - val_loss: 0.0188 - val_mse: 0.0188
# Epoch 158/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0186 - mse: 0.0186 - val_loss: 0.0185 - val_mse: 0.0185
# Epoch 159/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0195 - mse: 0.0195 - val_loss: 0.0185 - val_mse: 0.0185
# Epoch 160/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0179 - mse: 0.0179 - val_loss: 0.0181 - val_mse: 0.0181
# Epoch 161/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0182 - mse: 0.0182 - val_loss: 0.0196 - val_mse: 0.0196
# Epoch 162/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0179 - mse: 0.0179 - val_loss: 0.0181 - val_mse: 0.0181
# Epoch 163/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0186 - mse: 0.0186 - val_loss: 0.0189 - val_mse: 0.0189
# Epoch 164/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0196 - mse: 0.0196 - val_loss: 0.0183 - val_mse: 0.0183
# Epoch 165/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0182 - mse: 0.0182 - val_loss: 0.0194 - val_mse: 0.0194
# Epoch 166/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0185 - mse: 0.0185 - val_loss: 0.0181 - val_mse: 0.0181
# Epoch 167/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0178 - mse: 0.0178 - val_loss: 0.0203 - val_mse: 0.0203
# Epoch 168/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0183 - mse: 0.0183 - val_loss: 0.0180 - val_mse: 0.0180
# Epoch 169/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0185 - mse: 0.0185 - val_loss: 0.0178 - val_mse: 0.0178
# Epoch 170/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0183 - mse: 0.0183 - val_loss: 0.0180 - val_mse: 0.0180
# Epoch 171/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0182 - mse: 0.0182 - val_loss: 0.0184 - val_mse: 0.0184
# Epoch 172/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0183 - mse: 0.0183 - val_loss: 0.0180 - val_mse: 0.0180
# Epoch 173/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0180 - mse: 0.0180 - val_loss: 0.0183 - val_mse: 0.0183
# Epoch 174/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0191 - mse: 0.0191 - val_loss: 0.0207 - val_mse: 0.0207
# Epoch 175/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0189 - mse: 0.0189 - val_loss: 0.0193 - val_mse: 0.0193
# Epoch 176/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0183 - mse: 0.0183 - val_loss: 0.0195 - val_mse: 0.0195
# Epoch 177/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0182 - mse: 0.0182 - val_loss: 0.0181 - val_mse: 0.0181
# Epoch 178/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0180 - mse: 0.0180 - val_loss: 0.0183 - val_mse: 0.0183
# Epoch 179/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0181 - mse: 0.0181 - val_loss: 0.0178 - val_mse: 0.0178
# Epoch 180/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0181 - mse: 0.0181 - val_loss: 0.0180 - val_mse: 0.0180
# Epoch 181/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0182 - mse: 0.0182 - val_loss: 0.0179 - val_mse: 0.0179
# Epoch 182/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0182 - mse: 0.0182 - val_loss: 0.0179 - val_mse: 0.0179
# Epoch 183/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0180 - mse: 0.0180 - val_loss: 0.0180 - val_mse: 0.0180
# Epoch 184/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0189 - mse: 0.0189 - val_loss: 0.0185 - val_mse: 0.0185
# Epoch 185/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0184 - mse: 0.0184 - val_loss: 0.0187 - val_mse: 0.0187
# Epoch 186/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0186 - mse: 0.0186 - val_loss: 0.0196 - val_mse: 0.0196
# Epoch 187/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0198 - mse: 0.0198 - val_loss: 0.0179 - val_mse: 0.0179
# Epoch 188/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0183 - mse: 0.0183 - val_loss: 0.0180 - val_mse: 0.0180
# Epoch 189/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0186 - mse: 0.0186 - val_loss: 0.0179 - val_mse: 0.0179
# Epoch 190/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0188 - mse: 0.0188 - val_loss: 0.0180 - val_mse: 0.0180
# Epoch 191/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0185 - mse: 0.0185 - val_loss: 0.0202 - val_mse: 0.0202
# Epoch 192/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0187 - mse: 0.0187 - val_loss: 0.0192 - val_mse: 0.0192
# Epoch 193/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0191 - mse: 0.0191 - val_loss: 0.0187 - val_mse: 0.0187
# Epoch 194/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0182 - mse: 0.0182 - val_loss: 0.0190 - val_mse: 0.0190
# Epoch 195/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0180 - mse: 0.0180 - val_loss: 0.0181 - val_mse: 0.0181
# Epoch 196/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0180 - mse: 0.0180 - val_loss: 0.0180 - val_mse: 0.0180
# Epoch 197/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0181 - mse: 0.0181 - val_loss: 0.0179 - val_mse: 0.0179
# Epoch 198/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0182 - mse: 0.0182 - val_loss: 0.0185 - val_mse: 0.0185
# Epoch 199/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0180 - mse: 0.0180 - val_loss: 0.0180 - val_mse: 0.0180
# Epoch 200/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0185 - mse: 0.0185 - val_loss: 0.0181 - val_mse: 0.0181

# %%
#Graficar el MSE
fig, ax = plt.subplots(1, 1, figsize=(10,6))
ax.plot(np.sqrt(history.history['mse']), 'r', label='train')
ax.plot(np.sqrt(history.history['val_mse']), 'b' ,label='val')
ax.set_xlabel(r'Epoch', fontsize=20)
ax.set_ylabel(r'MSE', fontsize=20)
ax.legend()
ax.tick_params(labelsize=20)

# %%
#Evaluación del modelo

#Evaluación del modelo en los datos de prueba
score = model.evaluate(X_test,y_test)
print('Test mse:', score[1])
# Out:
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0181 - mse: 0.0181
# Test mse: 0.018148241564631462

# %%
#Predicción  y calcular R2

#Con datos del test
yhat = model.predict(X_test)
R2_score = r2_score(y_test,yhat)
xmin,xmax = min(y_test),max(y_test)
xline = np.linspace(xmin,xmax)
fig = plt.figure(figsize=(10,6))
plt.scatter(y_test,yhat,label='Estimation')
plt.plot(xline,xline,'k--',label='Perfect estimation')
plt.xlabel('Real output', fontsize=20)
plt.ylabel('Estimation output', fontsize=20)
plt.title('Test R^2=%0.4f'%R2_score, fontsize=20)
plt.legend()
plt.grid()
plt.show()
# Out:
# 7/7 [==============================] - 0s 2ms/step

# %%
print('R2:', R2_score)
# Out:
# R2: 0.9832179878642684

# %% [markdown]
# #### Ejemplo Multivariable (Más de una variable de entrada X)

# %%
m = 100;
X = np.linspace(-1,1,num=m)
[x1,x2] = np.meshgrid(X,X)
X = np.c_[x1.ravel(),x2.ravel()]
Y = X[:,0]**2+X[:,1]**2 

[m,ne] = np.shape(X)
Y = np.reshape(Y,(m,1))

from sklearn import preprocessing
X = preprocessing.scale(X)
Y = preprocessing.scale(Y)

#from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure(figsize=(20,10))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(X[:,0], X[:,1], Y)

# %%
#Dividimos los datos en test y train
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, Y,
                                                    test_size=0.2, random_state=42)

# %%
# Diseño del modelo

#Inicializo objeto
model = Sequential()

#Agregar capas

#Agregamos la primera capa de entrada
model.add(Dense(5, activation='relu', input_dim=2,name='input_layer')) #tanh
#Si quisiera añadir una capa oculta extra
#model.add(Dense(10, activation='tanh', name='hidden_layer'))
#Agregamos la capa de salida
model.add(Dense(1, activation='linear',name='output_layer'))

epochs = 200
momentum = 0.8
decay_rate = learning_rate/epochs
sgd = SGD(lr=learning_rate, decay=decay_rate, momentum=momentum)
model.compile(loss='mean_squared_error',
              optimizer=sgd, 
             metrics = ['mse'])
# Out:
# /Users/kalebavila/miniforge3/envs/keras/lib/python3.8/site-packages/keras/optimizers/optimizer_v2/gradient_descent.py:111: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)

# %%
#Ajustamos el modelo
history = model.fit(X_train, y_train, 
                   epochs=epochs, 
                   batch_size=100, 
                   validation_data=(X_test,y_test))
# Out:
# Epoch 1/200
# 80/80 [==============================] - 0s 4ms/step - loss: 0.5293 - mse: 0.5293 - val_loss: 0.0744 - val_mse: 0.0744
# Epoch 2/200
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0678 - mse: 0.0678 - val_loss: 0.0613 - val_mse: 0.0613
# Epoch 3/200
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0631 - mse: 0.0631 - val_loss: 0.0595 - val_mse: 0.0595
# Epoch 4/200
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0629 - mse: 0.0629 - val_loss: 0.0600 - val_mse: 0.0600
# Epoch 5/200
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0625 - mse: 0.0625 - val_loss: 0.0622 - val_mse: 0.0622
# Epoch 6/200
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0632 - mse: 0.0632 - val_loss: 0.0595 - val_mse: 0.0595
# Epoch 7/200
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0623 - mse: 0.0623 - val_loss: 0.0702 - val_mse: 0.0702
# Epoch 8/200
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0619 - mse: 0.0619 - val_loss: 0.0622 - val_mse: 0.0622
# Epoch 9/200
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0610 - mse: 0.0610 - val_loss: 0.0650 - val_mse: 0.0650
# Epoch 10/200
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0622 - mse: 0.0622 - val_loss: 0.0621 - val_mse: 0.0621
# Epoch 11/200
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0612 - mse: 0.0612 - val_loss: 0.0605 - val_mse: 0.0605
# Epoch 12/200
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0607 - mse: 0.0607 - val_loss: 0.0597 - val_mse: 0.0597
# Epoch 13/200
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0604 - mse: 0.0604 - val_loss: 0.0630 - val_mse: 0.0630
# Epoch 14/200
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0611 - mse: 0.0611 - val_loss: 0.0610 - val_mse: 0.0610
# Epoch 15/200
# 80/80 [==============================] - 0s 4ms/step - loss: 0.0602 - mse: 0.0602 - val_loss: 0.0594 - val_mse: 0.0594
# Epoch 16/200
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0607 - mse: 0.0607 - val_loss: 0.0662 - val_mse: 0.0662
# Epoch 17/200
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0608 - mse: 0.0608 - val_loss: 0.0588 - val_mse: 0.0588
# Epoch 18/200
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0607 - mse: 0.0607 - val_loss: 0.0592 - val_mse: 0.0592
# Epoch 19/200
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0604 - mse: 0.0604 - val_loss: 0.0635 - val_mse: 0.0635
# Epoch 20/200
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0608 - mse: 0.0608 - val_loss: 0.0628 - val_mse: 0.0628
# Epoch 21/200
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0616 - mse: 0.0616 - val_loss: 0.0600 - val_mse: 0.0600
# Epoch 22/200
# 80/80 [==============================] - 0s 4ms/step - loss: 0.0612 - mse: 0.0612 - val_loss: 0.0591 - val_mse: 0.0591
# Epoch 23/200
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0599 - mse: 0.0599 - val_loss: 0.0593 - val_mse: 0.0593
# Epoch 24/200
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0601 - mse: 0.0601 - val_loss: 0.0632 - val_mse: 0.0632
# Epoch 25/200
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0603 - mse: 0.0603 - val_loss: 0.0592 - val_mse: 0.0592
# Epoch 26/200
# 80/80 [==============================] - 0s 4ms/step - loss: 0.0606 - mse: 0.0606 - val_loss: 0.0600 - val_mse: 0.0600
# Epoch 27/200
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0599 - mse: 0.0599 - val_loss: 0.0604 - val_mse: 0.0604
# Epoch 28/200
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0597 - mse: 0.0597 - val_loss: 0.0605 - val_mse: 0.0605
# Epoch 29/200
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0599 - mse: 0.0599 - val_loss: 0.0602 - val_mse: 0.0602
# Epoch 30/200
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0602 - mse: 0.0602 - val_loss: 0.0610 - val_mse: 0.0610
# Epoch 31/200
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0614 - mse: 0.0614 - val_loss: 0.0594 - val_mse: 0.0594
# Epoch 32/200
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0598 - mse: 0.0598 - val_loss: 0.0614 - val_mse: 0.0614
# Epoch 33/200
# 80/80 [==============================] - 0s 4ms/step - loss: 0.0598 - mse: 0.0598 - val_loss: 0.0608 - val_mse: 0.0608
# Epoch 34/200
# 80/80 [==============================] - 0s 4ms/step - loss: 0.0596 - mse: 0.0596 - val_loss: 0.0608 - val_mse: 0.0608
# Epoch 35/200
# 80/80 [==============================] - 0s 4ms/step - loss: 0.0595 - mse: 0.0595 - val_loss: 0.0592 - val_mse: 0.0592
# Epoch 36/200
# 80/80 [==============================] - 0s 4ms/step - loss: 0.0595 - mse: 0.0595 - val_loss: 0.0611 - val_mse: 0.0611
# Epoch 37/200
# 80/80 [==============================] - 0s 4ms/step - loss: 0.0597 - mse: 0.0597 - val_loss: 0.0598 - val_mse: 0.0598
# Epoch 38/200
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0602 - mse: 0.0602 - val_loss: 0.0604 - val_mse: 0.0604
# Epoch 39/200
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0595 - mse: 0.0595 - val_loss: 0.0603 - val_mse: 0.0603
# Epoch 40/200
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0599 - mse: 0.0599 - val_loss: 0.0597 - val_mse: 0.0597
# Epoch 41/200
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0595 - mse: 0.0595 - val_loss: 0.0634 - val_mse: 0.0634
# Epoch 42/200
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0603 - mse: 0.0603 - val_loss: 0.0622 - val_mse: 0.0622
# Epoch 43/200
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0598 - mse: 0.0598 - val_loss: 0.0595 - val_mse: 0.0595
# Epoch 44/200
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0600 - mse: 0.0600 - val_loss: 0.0595 - val_mse: 0.0595
# Epoch 45/200
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0597 - mse: 0.0597 - val_loss: 0.0595 - val_mse: 0.0595
# Epoch 46/200
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0593 - mse: 0.0593 - val_loss: 0.0596 - val_mse: 0.0596
# Epoch 47/200
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0592 - mse: 0.0592 - val_loss: 0.0598 - val_mse: 0.0598
# Epoch 48/200
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0600 - mse: 0.0600 - val_loss: 0.0601 - val_mse: 0.0601
# Epoch 49/200
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0597 - mse: 0.0597 - val_loss: 0.0599 - val_mse: 0.0599
# Epoch 50/200
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0598 - mse: 0.0598 - val_loss: 0.0601 - val_mse: 0.0601
# Epoch 51/200
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0594 - mse: 0.0594 - val_loss: 0.0601 - val_mse: 0.0601
# Epoch 52/200
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0594 - mse: 0.0594 - val_loss: 0.0593 - val_mse: 0.0593
# Epoch 53/200
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0595 - mse: 0.0595 - val_loss: 0.0590 - val_mse: 0.0590
# Epoch 54/200
# 80/80 [==============================] - 0s 4ms/step - loss: 0.0593 - mse: 0.0593 - val_loss: 0.0602 - val_mse: 0.0602
# Epoch 55/200
# 80/80 [==============================] - 0s 4ms/step - loss: 0.0599 - mse: 0.0599 - val_loss: 0.0590 - val_mse: 0.0590
# Epoch 56/200
# 80/80 [==============================] - 0s 4ms/step - loss: 0.0592 - mse: 0.0592 - val_loss: 0.0611 - val_mse: 0.0611
# Epoch 57/200
# 80/80 [==============================] - 0s 4ms/step - loss: 0.0592 - mse: 0.0592 - val_loss: 0.0596 - val_mse: 0.0596
# Epoch 58/200
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0597 - mse: 0.0597 - val_loss: 0.0610 - val_mse: 0.0610
# Epoch 59/200
# 80/80 [==============================] - 0s 4ms/step - loss: 0.0594 - mse: 0.0594 - val_loss: 0.0594 - val_mse: 0.0594
# Epoch 60/200
# 80/80 [==============================] - 0s 4ms/step - loss: 0.0594 - mse: 0.0594 - val_loss: 0.0593 - val_mse: 0.0593
# Epoch 61/200
# 80/80 [==============================] - 0s 4ms/step - loss: 0.0592 - mse: 0.0592 - val_loss: 0.0605 - val_mse: 0.0605
# Epoch 62/200
# 80/80 [==============================] - 0s 4ms/step - loss: 0.0594 - mse: 0.0594 - val_loss: 0.0595 - val_mse: 0.0595
# Epoch 63/200
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0594 - mse: 0.0594 - val_loss: 0.0607 - val_mse: 0.0607
# Epoch 64/200
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0591 - mse: 0.0591 - val_loss: 0.0596 - val_mse: 0.0596
# Epoch 65/200
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0601 - mse: 0.0601 - val_loss: 0.0599 - val_mse: 0.0599
# Epoch 66/200
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0594 - mse: 0.0594 - val_loss: 0.0595 - val_mse: 0.0595
# Epoch 67/200
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0593 - mse: 0.0593 - val_loss: 0.0598 - val_mse: 0.0598
# Epoch 68/200
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0589 - mse: 0.0589 - val_loss: 0.0591 - val_mse: 0.0591
# Epoch 69/200
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0593 - mse: 0.0593 - val_loss: 0.0586 - val_mse: 0.0586
# Epoch 70/200
# 80/80 [==============================] - 0s 4ms/step - loss: 0.0592 - mse: 0.0592 - val_loss: 0.0592 - val_mse: 0.0592
# Epoch 71/200
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0597 - mse: 0.0597 - val_loss: 0.0609 - val_mse: 0.0609
# Epoch 72/200
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0591 - mse: 0.0591 - val_loss: 0.0588 - val_mse: 0.0588
# Epoch 73/200
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0591 - mse: 0.0591 - val_loss: 0.0601 - val_mse: 0.0601
# Epoch 74/200
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0592 - mse: 0.0592 - val_loss: 0.0588 - val_mse: 0.0588
# Epoch 75/200
# 80/80 [==============================] - 0s 4ms/step - loss: 0.0591 - mse: 0.0591 - val_loss: 0.0615 - val_mse: 0.0615
# Epoch 76/200
# 80/80 [==============================] - 0s 4ms/step - loss: 0.0593 - mse: 0.0593 - val_loss: 0.0597 - val_mse: 0.0597
# Epoch 77/200
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0592 - mse: 0.0592 - val_loss: 0.0596 - val_mse: 0.0596
# Epoch 78/200
# 80/80 [==============================] - 0s 4ms/step - loss: 0.0590 - mse: 0.0590 - val_loss: 0.0595 - val_mse: 0.0595
# Epoch 79/200
# 80/80 [==============================] - 0s 4ms/step - loss: 0.0589 - mse: 0.0589 - val_loss: 0.0589 - val_mse: 0.0589
# Epoch 80/200
# 80/80 [==============================] - 0s 4ms/step - loss: 0.0594 - mse: 0.0594 - val_loss: 0.0589 - val_mse: 0.0589
# Epoch 81/200
# 80/80 [==============================] - 0s 4ms/step - loss: 0.0591 - mse: 0.0591 - val_loss: 0.0614 - val_mse: 0.0614
# Epoch 82/200
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0590 - mse: 0.0590 - val_loss: 0.0593 - val_mse: 0.0593
# Epoch 83/200
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0592 - mse: 0.0592 - val_loss: 0.0593 - val_mse: 0.0593
# Epoch 84/200
# 80/80 [==============================] - 0s 4ms/step - loss: 0.0591 - mse: 0.0591 - val_loss: 0.0605 - val_mse: 0.0605
# Epoch 85/200
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0590 - mse: 0.0590 - val_loss: 0.0602 - val_mse: 0.0602
# Epoch 86/200
# 80/80 [==============================] - 0s 4ms/step - loss: 0.0591 - mse: 0.0591 - val_loss: 0.0589 - val_mse: 0.0589
# Epoch 87/200
# 80/80 [==============================] - 0s 4ms/step - loss: 0.0590 - mse: 0.0590 - val_loss: 0.0615 - val_mse: 0.0615
# Epoch 88/200
# 80/80 [==============================] - 0s 4ms/step - loss: 0.0593 - mse: 0.0593 - val_loss: 0.0594 - val_mse: 0.0594
# Epoch 89/200
# 80/80 [==============================] - 0s 4ms/step - loss: 0.0592 - mse: 0.0592 - val_loss: 0.0598 - val_mse: 0.0598
# Epoch 90/200
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0590 - mse: 0.0590 - val_loss: 0.0592 - val_mse: 0.0592
# Epoch 91/200
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0590 - mse: 0.0590 - val_loss: 0.0588 - val_mse: 0.0588
# Epoch 92/200
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0589 - mse: 0.0589 - val_loss: 0.0594 - val_mse: 0.0594
# Epoch 93/200
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0591 - mse: 0.0591 - val_loss: 0.0598 - val_mse: 0.0598
# Epoch 94/200
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0591 - mse: 0.0591 - val_loss: 0.0590 - val_mse: 0.0590
# Epoch 95/200
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0591 - mse: 0.0591 - val_loss: 0.0592 - val_mse: 0.0592
# Epoch 96/200
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0589 - mse: 0.0589 - val_loss: 0.0590 - val_mse: 0.0590
# Epoch 97/200
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0590 - mse: 0.0590 - val_loss: 0.0588 - val_mse: 0.0588
# Epoch 98/200
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0589 - mse: 0.0589 - val_loss: 0.0590 - val_mse: 0.0590
# Epoch 99/200
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0591 - mse: 0.0591 - val_loss: 0.0589 - val_mse: 0.0589
# Epoch 100/200
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0590 - mse: 0.0590 - val_loss: 0.0592 - val_mse: 0.0592
# Epoch 101/200
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0590 - mse: 0.0590 - val_loss: 0.0618 - val_mse: 0.0618
# Epoch 102/200
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0590 - mse: 0.0590 - val_loss: 0.0593 - val_mse: 0.0593
# Epoch 103/200
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0590 - mse: 0.0590 - val_loss: 0.0602 - val_mse: 0.0602
# Epoch 104/200
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0588 - mse: 0.0588 - val_loss: 0.0600 - val_mse: 0.0600
# Epoch 105/200
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0589 - mse: 0.0589 - val_loss: 0.0589 - val_mse: 0.0589
# Epoch 106/200
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0590 - mse: 0.0590 - val_loss: 0.0594 - val_mse: 0.0594
# Epoch 107/200
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0588 - mse: 0.0588 - val_loss: 0.0591 - val_mse: 0.0591
# Epoch 108/200
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0592 - mse: 0.0592 - val_loss: 0.0589 - val_mse: 0.0589
# Epoch 109/200
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0588 - mse: 0.0588 - val_loss: 0.0598 - val_mse: 0.0598
# Epoch 110/200
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0591 - mse: 0.0591 - val_loss: 0.0588 - val_mse: 0.0588
# Epoch 111/200
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0588 - mse: 0.0588 - val_loss: 0.0600 - val_mse: 0.0600
# Epoch 112/200
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0587 - mse: 0.0587 - val_loss: 0.0588 - val_mse: 0.0588
# Epoch 113/200
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0588 - mse: 0.0588 - val_loss: 0.0590 - val_mse: 0.0590
# Epoch 114/200
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0587 - mse: 0.0587 - val_loss: 0.0593 - val_mse: 0.0593
# Epoch 115/200
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0590 - mse: 0.0590 - val_loss: 0.0589 - val_mse: 0.0589
# Epoch 116/200
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0586 - mse: 0.0586 - val_loss: 0.0607 - val_mse: 0.0607
# Epoch 117/200
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0591 - mse: 0.0591 - val_loss: 0.0600 - val_mse: 0.0600
# Epoch 118/200
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0589 - mse: 0.0589 - val_loss: 0.0591 - val_mse: 0.0591
# Epoch 119/200
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0589 - mse: 0.0589 - val_loss: 0.0592 - val_mse: 0.0592
# Epoch 120/200
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0588 - mse: 0.0588 - val_loss: 0.0592 - val_mse: 0.0592
# Epoch 121/200
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0587 - mse: 0.0587 - val_loss: 0.0594 - val_mse: 0.0594
# Epoch 122/200
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0586 - mse: 0.0586 - val_loss: 0.0606 - val_mse: 0.0606
# Epoch 123/200
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0588 - mse: 0.0588 - val_loss: 0.0591 - val_mse: 0.0591
# Epoch 124/200
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0588 - mse: 0.0588 - val_loss: 0.0591 - val_mse: 0.0591
# Epoch 125/200
# 80/80 [==============================] - 0s 4ms/step - loss: 0.0587 - mse: 0.0587 - val_loss: 0.0593 - val_mse: 0.0593
# Epoch 126/200
# 80/80 [==============================] - 0s 4ms/step - loss: 0.0586 - mse: 0.0586 - val_loss: 0.0597 - val_mse: 0.0597
# Epoch 127/200
# 80/80 [==============================] - 0s 4ms/step - loss: 0.0588 - mse: 0.0588 - val_loss: 0.0592 - val_mse: 0.0592
# Epoch 128/200
# 80/80 [==============================] - 0s 4ms/step - loss: 0.0588 - mse: 0.0588 - val_loss: 0.0590 - val_mse: 0.0590
# Epoch 129/200
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0588 - mse: 0.0588 - val_loss: 0.0596 - val_mse: 0.0596
# Epoch 130/200
# 80/80 [==============================] - 0s 4ms/step - loss: 0.0587 - mse: 0.0587 - val_loss: 0.0592 - val_mse: 0.0592
# Epoch 131/200
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0589 - mse: 0.0589 - val_loss: 0.0595 - val_mse: 0.0595
# Epoch 132/200
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0589 - mse: 0.0589 - val_loss: 0.0588 - val_mse: 0.0588
# Epoch 133/200
# 80/80 [==============================] - 0s 4ms/step - loss: 0.0588 - mse: 0.0588 - val_loss: 0.0601 - val_mse: 0.0601
# Epoch 134/200
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0590 - mse: 0.0590 - val_loss: 0.0591 - val_mse: 0.0591
# Epoch 135/200
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0589 - mse: 0.0589 - val_loss: 0.0592 - val_mse: 0.0592
# Epoch 136/200
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0588 - mse: 0.0588 - val_loss: 0.0596 - val_mse: 0.0596
# Epoch 137/200
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0588 - mse: 0.0588 - val_loss: 0.0611 - val_mse: 0.0611
# Epoch 138/200
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0590 - mse: 0.0590 - val_loss: 0.0588 - val_mse: 0.0588
# Epoch 139/200
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0587 - mse: 0.0587 - val_loss: 0.0604 - val_mse: 0.0604
# Epoch 140/200
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0587 - mse: 0.0587 - val_loss: 0.0589 - val_mse: 0.0589
# Epoch 141/200
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0587 - mse: 0.0587 - val_loss: 0.0588 - val_mse: 0.0588
# Epoch 142/200
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0588 - mse: 0.0588 - val_loss: 0.0592 - val_mse: 0.0592
# Epoch 143/200
# 80/80 [==============================] - 0s 4ms/step - loss: 0.0588 - mse: 0.0588 - val_loss: 0.0593 - val_mse: 0.0593
# Epoch 144/200
# 80/80 [==============================] - 0s 4ms/step - loss: 0.0585 - mse: 0.0585 - val_loss: 0.0595 - val_mse: 0.0595
# Epoch 145/200
# 80/80 [==============================] - 0s 4ms/step - loss: 0.0587 - mse: 0.0587 - val_loss: 0.0588 - val_mse: 0.0588
# Epoch 146/200
# 80/80 [==============================] - 0s 4ms/step - loss: 0.0588 - mse: 0.0588 - val_loss: 0.0590 - val_mse: 0.0590
# Epoch 147/200
# 80/80 [==============================] - 0s 4ms/step - loss: 0.0587 - mse: 0.0587 - val_loss: 0.0595 - val_mse: 0.0595
# Epoch 148/200
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0588 - mse: 0.0588 - val_loss: 0.0598 - val_mse: 0.0598
# Epoch 149/200
# 80/80 [==============================] - 0s 4ms/step - loss: 0.0588 - mse: 0.0588 - val_loss: 0.0593 - val_mse: 0.0593
# Epoch 150/200
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0587 - mse: 0.0587 - val_loss: 0.0596 - val_mse: 0.0596
# Epoch 151/200
# 80/80 [==============================] - 0s 4ms/step - loss: 0.0588 - mse: 0.0588 - val_loss: 0.0588 - val_mse: 0.0588
# Epoch 152/200
# 80/80 [==============================] - 0s 4ms/step - loss: 0.0586 - mse: 0.0586 - val_loss: 0.0592 - val_mse: 0.0592
# Epoch 153/200
# 80/80 [==============================] - 0s 4ms/step - loss: 0.0587 - mse: 0.0587 - val_loss: 0.0591 - val_mse: 0.0591
# Epoch 154/200
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0588 - mse: 0.0588 - val_loss: 0.0591 - val_mse: 0.0591
# Epoch 155/200
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0588 - mse: 0.0588 - val_loss: 0.0595 - val_mse: 0.0595
# Epoch 156/200
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0588 - mse: 0.0588 - val_loss: 0.0588 - val_mse: 0.0588
# Epoch 157/200
# 80/80 [==============================] - 0s 5ms/step - loss: 0.0587 - mse: 0.0587 - val_loss: 0.0587 - val_mse: 0.0587
# Epoch 158/200
# 80/80 [==============================] - 0s 4ms/step - loss: 0.0588 - mse: 0.0588 - val_loss: 0.0597 - val_mse: 0.0597
# Epoch 159/200
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0586 - mse: 0.0586 - val_loss: 0.0606 - val_mse: 0.0606
# Epoch 160/200
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0588 - mse: 0.0588 - val_loss: 0.0592 - val_mse: 0.0592
# Epoch 161/200
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0586 - mse: 0.0586 - val_loss: 0.0600 - val_mse: 0.0600
# Epoch 162/200
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0588 - mse: 0.0588 - val_loss: 0.0590 - val_mse: 0.0590
# Epoch 163/200
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0585 - mse: 0.0585 - val_loss: 0.0587 - val_mse: 0.0587
# Epoch 164/200
# 80/80 [==============================] - 0s 4ms/step - loss: 0.0587 - mse: 0.0587 - val_loss: 0.0591 - val_mse: 0.0591
# Epoch 165/200
# 80/80 [==============================] - 0s 5ms/step - loss: 0.0586 - mse: 0.0586 - val_loss: 0.0595 - val_mse: 0.0595
# Epoch 166/200
# 80/80 [==============================] - 0s 4ms/step - loss: 0.0586 - mse: 0.0586 - val_loss: 0.0587 - val_mse: 0.0587
# Epoch 167/200
# 80/80 [==============================] - 0s 4ms/step - loss: 0.0586 - mse: 0.0586 - val_loss: 0.0588 - val_mse: 0.0588
# Epoch 168/200
# 80/80 [==============================] - 0s 4ms/step - loss: 0.0586 - mse: 0.0586 - val_loss: 0.0590 - val_mse: 0.0590
# Epoch 169/200
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0587 - mse: 0.0587 - val_loss: 0.0592 - val_mse: 0.0592
# Epoch 170/200
# 80/80 [==============================] - 0s 4ms/step - loss: 0.0587 - mse: 0.0587 - val_loss: 0.0592 - val_mse: 0.0592
# Epoch 171/200
# 80/80 [==============================] - 0s 4ms/step - loss: 0.0586 - mse: 0.0586 - val_loss: 0.0590 - val_mse: 0.0590
# Epoch 172/200
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0588 - mse: 0.0588 - val_loss: 0.0591 - val_mse: 0.0591
# Epoch 173/200
# 80/80 [==============================] - 0s 4ms/step - loss: 0.0586 - mse: 0.0586 - val_loss: 0.0590 - val_mse: 0.0590
# Epoch 174/200
# 80/80 [==============================] - 0s 4ms/step - loss: 0.0588 - mse: 0.0588 - val_loss: 0.0590 - val_mse: 0.0590
# Epoch 175/200
# 80/80 [==============================] - 0s 4ms/step - loss: 0.0587 - mse: 0.0587 - val_loss: 0.0592 - val_mse: 0.0592
# Epoch 176/200
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0587 - mse: 0.0587 - val_loss: 0.0593 - val_mse: 0.0593
# Epoch 177/200
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0587 - mse: 0.0587 - val_loss: 0.0592 - val_mse: 0.0592
# Epoch 178/200
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0586 - mse: 0.0586 - val_loss: 0.0598 - val_mse: 0.0598
# Epoch 179/200
# 80/80 [==============================] - 0s 4ms/step - loss: 0.0585 - mse: 0.0585 - val_loss: 0.0591 - val_mse: 0.0591
# Epoch 180/200
# 80/80 [==============================] - 0s 4ms/step - loss: 0.0586 - mse: 0.0586 - val_loss: 0.0599 - val_mse: 0.0599
# Epoch 181/200
# 80/80 [==============================] - 0s 4ms/step - loss: 0.0587 - mse: 0.0587 - val_loss: 0.0590 - val_mse: 0.0590
# Epoch 182/200
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0585 - mse: 0.0585 - val_loss: 0.0595 - val_mse: 0.0595
# Epoch 183/200
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0587 - mse: 0.0587 - val_loss: 0.0590 - val_mse: 0.0590
# Epoch 184/200
# 80/80 [==============================] - 0s 4ms/step - loss: 0.0588 - mse: 0.0588 - val_loss: 0.0600 - val_mse: 0.0600
# Epoch 185/200
# 80/80 [==============================] - 0s 4ms/step - loss: 0.0587 - mse: 0.0587 - val_loss: 0.0589 - val_mse: 0.0589
# Epoch 186/200
# 80/80 [==============================] - 0s 4ms/step - loss: 0.0586 - mse: 0.0586 - val_loss: 0.0593 - val_mse: 0.0593
# Epoch 187/200
# 80/80 [==============================] - 0s 4ms/step - loss: 0.0587 - mse: 0.0587 - val_loss: 0.0589 - val_mse: 0.0589
# Epoch 188/200
# 80/80 [==============================] - 0s 4ms/step - loss: 0.0587 - mse: 0.0587 - val_loss: 0.0589 - val_mse: 0.0589
# Epoch 189/200
# 80/80 [==============================] - 0s 4ms/step - loss: 0.0586 - mse: 0.0586 - val_loss: 0.0589 - val_mse: 0.0589
# Epoch 190/200
# 80/80 [==============================] - 0s 4ms/step - loss: 0.0587 - mse: 0.0587 - val_loss: 0.0588 - val_mse: 0.0588
# Epoch 191/200
# 80/80 [==============================] - 0s 4ms/step - loss: 0.0586 - mse: 0.0586 - val_loss: 0.0593 - val_mse: 0.0593
# Epoch 192/200
# 80/80 [==============================] - 0s 4ms/step - loss: 0.0586 - mse: 0.0586 - val_loss: 0.0590 - val_mse: 0.0590
# Epoch 193/200
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0586 - mse: 0.0586 - val_loss: 0.0589 - val_mse: 0.0589
# Epoch 194/200
# 80/80 [==============================] - 0s 4ms/step - loss: 0.0585 - mse: 0.0585 - val_loss: 0.0589 - val_mse: 0.0589
# Epoch 195/200
# 80/80 [==============================] - 0s 4ms/step - loss: 0.0586 - mse: 0.0586 - val_loss: 0.0590 - val_mse: 0.0590
# Epoch 196/200
# 80/80 [==============================] - 0s 4ms/step - loss: 0.0586 - mse: 0.0586 - val_loss: 0.0593 - val_mse: 0.0593
# Epoch 197/200
# 80/80 [==============================] - 0s 4ms/step - loss: 0.0586 - mse: 0.0586 - val_loss: 0.0593 - val_mse: 0.0593
# Epoch 198/200
# 80/80 [==============================] - 0s 4ms/step - loss: 0.0586 - mse: 0.0586 - val_loss: 0.0588 - val_mse: 0.0588
# Epoch 199/200
# 80/80 [==============================] - 0s 4ms/step - loss: 0.0587 - mse: 0.0587 - val_loss: 0.0592 - val_mse: 0.0592
# Epoch 200/200
# 80/80 [==============================] - 0s 4ms/step - loss: 0.0586 - mse: 0.0586 - val_loss: 0.0590 - val_mse: 0.0590

# %%
#Graficar el MSE
fig, ax = plt.subplots(1, 1, figsize=(10,6))
ax.plot(np.sqrt(history.history['mse']), 'r', label='train')
ax.plot(np.sqrt(history.history['val_mse']), 'b' ,label='val')
ax.set_xlabel(r'Epoch', fontsize=20)
ax.set_ylabel(r'MSE', fontsize=20)
ax.legend()
ax.tick_params(labelsize=20)

# %%
#Evaluación del modelo

#Evaluación del modelo en los datos de prueba
score = model.evaluate(X_test,y_test)
print('Test mse:', score[1])
# Out:
# 63/63 [==============================] - 0s 3ms/step - loss: 0.0590 - mse: 0.0590
# Test mse: 0.05899357423186302

# %%
#Predicción  y calcular R2

#Con datos del test
yhat = model.predict(X_test)
R2_score = r2_score(y_test,yhat)
xmin,xmax = min(y_test),max(y_test)
xline = np.linspace(xmin,xmax)
fig = plt.figure(figsize=(10,6))
plt.scatter(y_test,yhat,label='Estimation')
plt.plot(xline,xline,'k--',label='Perfect estimation')
plt.xlabel('Real output', fontsize=20)
plt.ylabel('Estimation output', fontsize=20)
plt.title('Test R^2=%0.4f'%R2_score, fontsize=20)
plt.legend()
plt.grid()
plt.show()
# Out:
# 63/63 [==============================] - 0s 1ms/step

# %%
print('R2:', R2_score)
# Out:
# R2: 0.9403815947798204

# %% [markdown]
# #### Ejemplo Cross Validation

# %%
### Cross Validation
from keras.wrappers.scikit_learn import KerasRegressor
from sklearn.model_selection import cross_val_score

# %%
# Crear función que regresa una red neuronal compilada
def create_network():
    
    # Iniciar objeto de red neuronal
    network = Sequential()

    # Añadir una capa de entrada
    network.add(Dense(5, activation='tanh', input_dim=2,name='input_layer')) #Relu

    # Añadir capa oculta
    #network.add(Dense(10, activation='relu')) #tanh

    # Añadir capa de salida
    network.add(Dense(1, activation='linear'))
    
    opt = keras.optimizers.SGD(lr=learning_rate,momentum=momentum,
                           decay=decay_rate)
    
    # Compilar la red neuronal
    network.compile(loss='mean_squared_error', 
                    optimizer=opt, 
                    metrics=['mse']) 
    
    #regresa la red compilada
    return network

# %%
# Hacer el modelo en keras para que pueda ser usado por scikit-learn
neural_network = KerasRegressor(build_fn=create_network, 
                                 epochs=200, 
                                 batch_size=100, 
                                 verbose=0)
# Out:
# <ipython-input-26-fec25c451ab0>:2: DeprecationWarning: KerasRegressor is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead. See https://www.adriangb.com/scikeras/stable/migration.html for help migrating.
#   neural_network = KerasRegressor(build_fn=create_network,

# %%
# Evaluar la red neuronal usando 10-fold cross-validation
print('MSE:', (-cross_val_score(neural_network, X, Y, cv=10,  scoring='neg_mean_squared_error')).mean())
# Out:
# /Users/kalebavila/miniforge3/envs/keras/lib/python3.8/site-packages/keras/optimizers/optimizer_v2/gradient_descent.py:111: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# /Users/kalebavila/miniforge3/envs/keras/lib/python3.8/site-packages/keras/optimizers/optimizer_v2/gradient_descent.py:111: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# /Users/kalebavila/miniforge3/envs/keras/lib/python3.8/site-packages/keras/optimizers/optimizer_v2/gradient_descent.py:111: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# /Users/kalebavila/miniforge3/envs/keras/lib/python3.8/site-packages/keras/optimizers/optimizer_v2/gradient_descent.py:111: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# /Users/kalebavila/miniforge3/envs/keras/lib/python3.8/site-packages/keras/optimizers/optimizer_v2/gradient_descent.py:111: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# /Users/kalebavila/miniforge3/envs/keras/lib/python3.8/site-packages/keras/optimizers/optimizer_v2/gradient_descent.py:111: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# /Users/kalebavila/miniforge3/envs/keras/lib/python3.8/site-packages/keras/optimizers/optimizer_v2/gradient_descent.py:111: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)

# %%
print('R2:', (cross_val_score(neural_network, X, Y, cv=10,  scoring='r2')).mean())

# %% [markdown]
# ### Optimización de hiperparámetros
#
# **GridSearch**
#
# ![GridSearch](https://www.yourdatateacher.com/wp-content/uploads/2021/03/image-7.png)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import r2_score,mean_squared_error,make_scorer

# %%
def create_model(lr=0.1,momentum=0.8):
    # Neural network architecture
    model = Sequential()
    model.add(Dense(5,activation='tanh',input_dim=2))
    model.add(Dense(1,activation='linear'))
    
    # Optimizer configuration
    opt = keras.optimizers.SGD(lr=lr,momentum=momentum)
    model.compile(loss = 'mean_squared_error',
                  optimizer=opt,
                  metrics=['mse'])
    return model

epochs = 200
batch_size = 100
#learning_rate = 0.1
#decay_rate = learning_rate/epochs
#momentum = 0.8

model_search = KerasRegressor(build_fn=create_model,epochs=epochs)

# Definir los parámetros del grid search
lr = [0.1, 0.05, 0.01]
momentum = [0.8, 0.6, 0.4]
param_grid = dict(lr=lr,momentum=momentum)

selection_score = make_scorer(r2_score) #r2
#selection_score = make_scorer(mean_squared_error,greater_is_better=False) #MSE

grid = GridSearchCV(estimator=model_search, param_grid=param_grid,
                    cv=2,return_train_score=True,
                    scoring=selection_score)

grid_result = grid.fit(X_train, y_train)

# Imprimir resultados
# means es de la R2 que pusimos antes
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
    print(f' mean={mean:.4}, std={stdev:.4} using {param}')

# %%
print('Mejores parámetros:')
print(grid_result.best_params_)
print('Mejores score:')
print(grid_result.best_score_)
my_model= grid_result.best_estimator_
#my_model.model.summary()
weights = my_model.model.get_weights() #pesos

# %%
#Diseñar modelo con métricas optimizadas
epochs = 200
learning_rate = 0.05
decay_rate = learning_rate/epochs
momentum = 0.8

# Red neuronal
model = Sequential()
model.add(Dense(5,activation='tanh',input_dim=2))
model.add(Dense(1,activation='linear'))

# Optimizer configuration
#gradiente descendente
opt = keras.optimizers.SGD(lr=learning_rate,momentum=momentum,
                           decay=decay_rate,nesterov=True)
model.compile(loss = 'mean_squared_error',
              optimizer=opt,
              metrics=['mse'])

#Ajustar modelo
model_history = model.fit(X_train,y_train,
                    epochs=epochs,
                    batch_size=200,
                    validation_data=(X_test,y_test))

#performance
score = model.evaluate(X_test,y_test)
print('Test loss:', score[0])
print('Test mse:', score[1])

# %%
# Graficar el mse
fig, ax = plt.subplots(1, 1, figsize=(10,6))
ax.plot(np.sqrt(model_history.history['mse']), 'r', label='train')
ax.plot(np.sqrt(model_history.history['val_mse']), 'b' ,label='val')
ax.set_xlabel(r'Epoch', fontsize=20)
ax.set_ylabel(r'MSE', fontsize=20)
ax.legend()
ax.tick_params(labelsize=20)

# %%
#Predicción  y calcular R2
yhat = model.predict(X_test)

R2_score = r2_score(y_test,yhat)

xmin,xmax = min(y_test),max(y_test)
xline = np.linspace(xmin,xmax)
fig = plt.figure(figsize=(10,6))
plt.scatter(y_test,yhat,label='Estimation')
plt.plot(xline,xline,'k--',label='Perfect estimation')
plt.xlabel('Real output', fontsize=20)
plt.ylabel('Estimation output', fontsize=20)
plt.title('Test R^2=%0.4f'%R2_score, fontsize=20)
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# ### Ventajas y desventajas de las redes neuronales
#
# #### Ventajas
#
# - Capacidad de trabajar con información incompleta
# - Si algo llega a fallar en una neurona, se pueden aún obtener resultados - Tolerantes a fallas
# - Tienen la capacidad de aprender por sí mismas y generar resultados que no se limitan a la información que se les dió al principio.
# - Capacidad de procesamiento en paralelo
# - Autoorganización: la capacidad de agrupar y clasificar grandes cantidades de datos hace que las redes neuronales sean especialmente adecuadas para organizar los complicados problemas visuales que plantea el análisis de imágenes
#
# #### Desventajas
#
# - Debido a su naturaleza de "caja negra" se pierde interpretación del modelo
# - Usualmente requieren muchos más datos que los modelos tradicionales
# - Si hay demasiados datos, la red neuronal requiere procesadores con gran poder de procesamiento
# - No hay regla específica para determinar la estructura de la red - Prueba y error
# - Pueden llegar a convertirse muy complejas

# %% [markdown]
# #### Algunas referencias
#
# - https://keras.io/guides/sequential_model/
# - https://keras.io/api/layers/activations/
# - https://keras.io/optimizers/
# - https://playground.tensorflow.org/#activation=tanh&batchSize=10&dataset=spiral&regDataset=reg-gauss&learningRate=0.03&regularizationRate=0.003&noise=20&networkShape=4&seed=0.82538&showTestData=false&discretize=false&percTrainData=50&x=true&y=true&xTimesY=false&xSquared=false&ySquared=false&cosX=false&sinX=false&cosY=false&sinY=false&collectStats=false&problem=regression&initZero=false&hideText=false
